# %% [markdown]
# <a href="https://colab.research.google.com/github/LoulouiseBipBip/PRA3024/blob/main/Grav_Waves_Challenge1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install gwosc
! pip install gwpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ligo-segments: filename=ligo_segments-1.4.0-cp310-cp310-linux_x86_64.whl size=99253 sha256=c14bbd71612e05c2d22b60b64da1ddaebd74376a449bcbfb95f432b0b5b14e00
#   Stored in directory: /root/.cache/pip/wheels/6d/48/d1/3466977be4e41ba57f92ad0d5619f083df43cf319a151c4e06
# Successfully built ligo-segments
# ...

# %%
import gwosc
from gwosc.datasets import find_datasets
from gwosc import datasets
from gwosc.datasets import event_gps
from gwpy.timeseries import TimeSeries

# %%
#GEtting the data in Time series
T = TimeSeries.read('challenge1.gwf', channel="H1:CHALLENGE1")
print("The sampling rate is")
print(T.dt)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-fa76b0db481b> in <cell line: 2>()
#       1 #GEtting the data in Time series
# ----> 2 T = TimeSeries.read('challenge1.gwf', channel="H1:CHALLENGE1")
#       3 print("The sampling rate is")
#       4 print(T.dt)
#
# /usr/local/lib/python3.10/dist-packages/gwpy/timeseries/core.py in read(cls, source, *args, **kwargs)
#     308         -----"""
#     309         from .io.core import read as timeseries_reader
# --> 310         return timeseries_reader(cls, source, *args, **kwargs)
#     311
#     312     def write(self, target, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/gwpy/timeseries/io/core.py in read(cls, source, *args, **kwargs)
#      48     )
#      49     # read
# ---> 50     return io_read_multi(joiner, cls, source, *args, **kwargs)
#      51
#      52
#
# ...

# %%
print("The duration of the data is:")
print(T.duration)
# Out:
# The duration of the data is:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-85e9110c6a74> in <cell line: 2>()
#       1 print("The duration of the data is:")
# ----> 2 print(T.duration)
#
# NameError: name 'T' is not defined

# %%
#Time plot
T.plot()
plot.show()
# Out:
# <Plot size 1200x400 with 1 Axes>

# %%
hq = T.q_transform(frange=(30, 300), qrange=(30, 50), outseg=(0,+4))
plot = hq.plot()
plot.colorbar(label="Normalised energy")
ax = plot.gca()
ax.set_yscale("log")
plot.show  # refresh
# Out:
# <bound method Plot.show of <Plot size 1200x600 with 2 Axes>>
# <Plot size 1200x600 with 2 Axes>
